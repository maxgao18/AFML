# %%
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# # Gaussian Noise

# %%
plt.rcParams["figure.figsize"] = (20, 5)

series = np.random.normal(size=1000)
plt.plot(series)

# %% [markdown]
# ## ADF Test

# %%
result = adfuller(series)
print("ADF Statistic: %f" % result[0])
print("p-value: %f" % result[1])
print("Critical Values:")
for key, value in result[4].items():
    print("\t%s: %.3f" % (key, value))
# Out:
# ADF Statistic: -32.447728
# p-value: 0.000000
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# # Cumulative Sum of Noise (Non Stationary)

# %%
cumsum = series.cumsum()
plt.plot(cumsum)

# %%
result = adfuller(cumsum)
print("ADF Statistic: %f" % result[0])
print("p-value: %f" % result[1])
print("Critical Values:")
for key, value in result[4].items():
    print("\t%s: %.3f" % (key, value))
# Out:
# ADF Statistic: -1.793708
# p-value: 0.383590
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# # Diff of Gaussian Noise

# %%
diff = np.diff(series)
plt.plot(diff)

# %%
result = adfuller(diff)
print("ADF Statistic: %f" % result[0])
print("p-value: %f" % result[1])
print("Critical Values:")
for key, value in result[4].items():
    print("\t%s: %.3f" % (key, value))
# Out:
# ADF Statistic: -13.252062
# p-value: 0.000000
# Critical Values:
# 	1%: -3.437
# 	5%: -2.864
# 	10%: -2.568
