# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import mplfinance as mplf
import numpy as np
import pandas as pd

import bars
import d
import microstructure

# %%
plt.rcParams["figure.figsize"] = (20, 8)
data = d.fetch("data/future/daily", "ES.csv")
data["log_close"] = np.log(data["Close"])

# %% [markdown]
# # Corwin-Schultz Spread Estimate

# %%
rolling_window=1

data["spread_pct"] = microstructure.corwin_schultz_spread_estimate(
    data, rolling_window=rolling_window, as_percent_of_price=True
)
data["spread"] = microstructure.corwin_schultz_spread_estimate(
    data, rolling_window=rolling_window
)
data[["log_close", "spread_pct"]].plot(secondary_y="spread_pct")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data[["log_close", "spread"]].plot(secondary_y="spread")
# Out:
# <AxesSubplot:xlabel='Date'>
